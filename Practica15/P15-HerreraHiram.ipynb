# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
def relajacion(phi,rho,V,tol = 1e-3):
    Nxdim,Nydim = np.shape(phi)
    phi_old = np.zeros(np.shape(phi))
    n = 0
    while (abs(phi_old-phi)>tol).any():
        phi_old = phi.copy()
        for i in range(1,Nxdim-1):
            for j in range(1,Nydim-1):
                if phi[i,j] == V or Phi[i,j] == -V:
                    continue
                else:
                    phi[i,j] = 0.25*(phi[i+1,j]+phi[i-1,j]+phi[i,j+1]+phi[i,j-1])-np.pi*rho[i,j]
        n+=1
    print('Iteraciones:',n) 
    return phi

# %%
# Problema 1
V = 100.
Phi = np.zeros([100,100])
rho = np.zeros([100,100])
Phi[:,0] = V
Xdim,Ydim = np.shape(Phi)
X,Y = np.arange(Xdim),np.arange(Ydim)
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.title('Condición Inicial')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
Phi = relajacion(Phi,rho,V)
# Out:
# Iteraciones: 3660

# %%
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
x,y = np.meshgrid(X,Y)
ax = plt.axes(projection='3d')
ax.plot_surface(x,y,Phi)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel(r'$\Phi(x,y)$')
plt.show()

# %%
# Problema 2
V = 100.
d = 10
w = 50
Phi = np.zeros([100,100])
rho = np.zeros([100,100])
Xdim,Ydim = np.shape(Phi)
X,Y = np.arange(Xdim),np.arange(Ydim)
Phi[int(Ydim/2 + d/2),int(Xdim/2-w/2):int(Xdim/2+w/2)] = V
Phi[int(Ydim/2 - d/2),int(Xdim/2-w/2):int(Xdim/2+w/2)] = -V
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.title('Condición Inicial')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
Phi = relajacion(Phi,rho,V)
# Out:
# Iteraciones: 1749

# %%
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
x,y = np.meshgrid(X,Y)
ax = plt.axes(projection='3d')
ax.plot_surface(y,x,Phi)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel(r'$\Phi(x,y)$')
plt.show()

# %%
# Problema 3
V = 100.
L = 25
Phi = np.zeros([100,100])
rho = np.zeros([100,100])
Xdim,Ydim = np.shape(Phi)
X,Y = np.arange(Xdim),np.arange(Ydim)
Phi[int(Ydim/2-L/2):int(Ydim/2+L/2),int(Xdim/2-L/2):int(Xdim/2+L/2)] = V
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.title('Condición Inicial')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
Phi = relajacion(Phi,rho,V)
# Out:
# Iteraciones: 1664

# %%
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
x,y = np.meshgrid(X,Y)
ax = plt.axes(projection='3d')
ax.plot_surface(x,y,Phi)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel(r'$\Phi(x,y)$')
plt.show()

# %%
#Problema 4:
V = 100.
a = 5
b = 15
Phi = np.zeros([100,100])
rho = np.zeros([100,100])
Xdim,Ydim = np.shape(Phi)
X,Y = np.arange(Xdim),np.arange(Ydim)
y,x = np.ogrid[-Xdim/2:Xdim/2,-Ydim/2:Ydim/2]
Mask_a = x**2+y**2 <= a**2
Mask_b = x**2+y**2 <= b**2
Phi[Mask_b] = V
Phi[Mask_a] = -V
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.title('Condición Inicial')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
Phi = relajacion(Phi,rho,V)
# Out:
# Iteraciones: 1674

# %%
plt.pcolor(X,Y,Phi,cmap='jet')
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
x,y = np.meshgrid(X,Y)
ax = plt.axes(projection='3d')
ax.plot_surface(x,y,Phi)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel(r'$\Phi(x,y)$')
plt.show()
